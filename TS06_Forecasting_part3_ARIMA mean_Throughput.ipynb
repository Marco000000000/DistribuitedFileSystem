# %% [markdown]
# ## ARIMA (AutoRegressive Integrated Moving Average)
#
# * Used to understand data and forecast future values
# * It works well when data does not depend on external factors
# * Several models (ARIMA, SARIMA, SARIMAX)
# * "Integrated" part of the model helps to manage non-stationary data
#
# #### ARIMA(p,d,q)
# * AR(p) : Autoregration model that exploits relationship between the current observation and the previous ones over a given period (and a stochastic, not predictable term)
# * I(d) : differencing process
# * MA(q) : it exploits dependency between the current observation and the residual error from a moving average model applied to q lagged observations

# %%
# !pip install pmdarima
import pandas as pd
import matplotlib.pyplot as plt
import json
# %matplotlib inline

file_p = 'mean_Throughput.json'

# Load specific forecasting tools
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from pmdarima import auto_arima # for determining ARIMA orders
import statsmodels.api
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

tsr = pd.read_json(file_p)
# Out:
# Requirement already satisfied: pmdarima in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (3.0.8)
# Requirement already satisfied: numpy>=1.21.2 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (1.26.3)
# Requirement already satisfied: pandas>=0.19 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (2.1.4)
# Requirement already satisfied: scikit-learn>=0.22 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (1.4.0)
# Requirement already satisfied: scipy>=1.3.2 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (1.12.0)
# Requirement already satisfied: statsmodels>=0.13.2 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (2.1.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (69.0.3)
# Requirement already satisfied: packaging>=17.1 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pmdarima) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.4 in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in d:\programmazione\vscode\python\distribuitedfilesystem\.venv\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
# try to predict trend: Extract trend
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(tsr[1][:], model='additive', period=1)
trend = result.trend.dropna()
trend.plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
#Check stationarity (p_value < 0.05)
from statsmodels.tsa.stattools import adfuller
adft = adfuller(trend,autolag='AIC')

#print them with info
print('Augmented Dickey-Fuller Test trends')

out = pd.Series(adft[0:4],index=['ADF test statistic','p-value','# lags used','# observations'])

for key,val in adft[4].items():
    out[f'critical value ({key})']=val
print(out)
# Out:
# Augmented Dickey-Fuller Test trends
# ADF test statistic       -2.307215
# p-value                   0.169652
# # lags used              18.000000
# # observations          484.000000
# critical value (1%)      -3.443933
# critical value (5%)      -2.867530
# critical value (10%)     -2.569961
# dtype: float64

# %%
#Lags plot
from pandas.plotting import lag_plot

lag_plot(trend)  #check resid, seasonal
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
plot_acf(trend,title='acf',lags=40)

# %%
plot_pacf(trend,title='pacf',lags=40)

# %% [markdown]
# If the PACF displays a sharp cutoff while the ACF decays more slowly (i.e., has significant spikes at higher lags), we say that the stationarized series displays an "AR signature," meaning that the autocorrelation pattern can be explained more easily by adding AR terms than by adding MA terms.

# %%
auto_arima(trend)
# auto_arima(trend,seasonal=True,m=25)
# Out:
# ARIMA(order=(0, 2, 0), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
trend.describe()
# Out:
# count    5.030000e+02
# mean     5.032535e+06
# std      2.203562e+06
# min      7.151252e+05
# 25%      3.732384e+06
# 50%      5.844848e+06
# 75%      6.393138e+06
# max      8.514702e+06
# Name: trend, dtype: float64

# %%
train = trend.iloc[:250]
test = trend.iloc[250:]

# %%
model = statsmodels.api.tsa.ARIMA(train, order=(0,2,0))
# model = statsmodels.api.tsa.SARIMAX(train,order=(3,0,0),seasonal_order=(0,0,0,25))

# %%
trends = model.fit()

# %%
trends.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  trend   No. Observations:                  250
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -2933.655
# Date:                Sun, 28 Jan 2024   AIC                           5869.310
# Time:                        21:14:27   BIC                           5872.823
# Sample:                             0   HQIC                          5870.724
#                                 - 250
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.093e+09   3.81e+07     28.672      0.000    1.02e+09    1.17e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              1274.21
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                             0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start=len(train)
end=len(train)+len(test)-1
predictions = trends.predict(start=start, end=end, dynamic=False, typ='linear')

# %% [markdown]
# Passing <tt>dynamic=False</tt> means that forecasts at each point are generated using the full history up to that point (all lagged values).
#
# Passing <tt>typ='levels'</tt> predicts the levels of the original endogenous variables. If we'd used the default <tt>typ='linear'</tt> we would have seen linear predictions in terms of the differenced endogenous variables.

# %%
#define size
plt.figure(figsize=(24,10))
#add axes labels and a title
plt.ylabel('Values', fontsize=14)
plt.xlabel('Time', fontsize=14)
plt.title('Values over time', fontsize=16)
plt.plot(train,"-", label = 'test')
plt.plot(test,"-", label = 'test')
plt.plot(predictions,"--", label = 'pred')
#add legend
plt.legend(title='Series')

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test, predictions)
error
# Out:
# 13479039272852.883

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test, predictions)
error
# Out:
# 3671381.112449766

# %%
trend.describe()
# Out:
# count    5.030000e+02
# mean     5.032535e+06
# std      2.203562e+06
# min      7.151252e+05
# 25%      3.732384e+06
# 50%      5.844848e+06
# 75%      6.393138e+06
# max      8.514702e+06
# Name: trend, dtype: float64

# %%
model = statsmodels.api.tsa.ARIMA(trend,order=(3,2,5))
trends = model.fit()
fcast = trends.predict(len(trend),len(trend)+72,typ='linear')

# %%
#define size
plt.figure(figsize=(24,10))
#add axes labels and a title
plt.ylabel('Values', fontsize=14)
plt.xlabel('Time', fontsize=14)
plt.title('Values over time', fontsize=16)
plt.plot(trend.iloc[-250:],"-", label = 'test')
plt.plot(fcast,"--", label = 'fcast')
#add legend
plt.legend(title='Series')
